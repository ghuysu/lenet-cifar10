# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from keras.datasets import cifar10
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import ImageDataGenerator
import numpy as np
import matplotlib.pyplot as plt

# Load CIFAR-10 dataset
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# Preprocess data
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.1, random_state=0)
X_train = X_train.astype('float32') / 255.0
X_valid = X_valid.astype('float32') / 255.0
X_test = X_test.astype('float32') / 255.0
y_train = to_categorical(y_train, 10)
y_valid = to_categorical(y_valid, 10)
y_test = to_categorical(y_test, 10)

# Data augmentation
datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    fill_mode='nearest'
)

# Define the model
model = models.Sequential([
    layers.Conv2D(filters=32, kernel_size=(3, 3), padding='same', activation='relu', input_shape=(32, 32, 3)),
    layers.BatchNormalization(),
    layers.Conv2D(filters=32, kernel_size=(3, 3), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(rate=0.2),
    layers.Conv2D(filters=64, kernel_size=(3, 3), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.Conv2D(filters=64, kernel_size=(3, 3), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(rate=0.3),
    layers.Conv2D(filters=128, kernel_size=(3, 3), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.Conv2D(filters=128, kernel_size=(3, 3), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(rate=0.4),
    layers.Conv2D(filters=256, kernel_size=(3, 3), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.Conv2D(filters=256, kernel_size=(3, 3), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(rate=0.5),
    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# Compile model
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0005)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model with data augmentation
history = model.fit(datagen.flow(X_train, y_train, batch_size=64), epochs=40, validation_data=(X_valid, y_valid))

# Evaluate model on test data
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print("Test loss:", test_loss)
print("Test accuracy:", test_accuracy)

# Plot training history
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

plt.show()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 13s 0us/step
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 32, 32, 32)        896
#
#  batch_normalization_8 (Bat  (None, 32, 32, 32)        128
#  chNormalization)
#
#  conv2d_9 (Conv2D)           (None, 32, 32, 32)        9248
#
#  batch_normalization_9 (Bat  (None, 32, 32, 32)        128
#  chNormalization)
#
#  max_pooling2d_4 (MaxPoolin  (None, 16, 16, 32)        0
#  g2D)
#
#  dropout_4 (Dropout)         (None, 16, 16, 32)        0
#
#  conv2d_10 (Conv2D)          (None, 16, 16, 64)        18496
#
#  batch_normalization_10 (Ba  (None, 16, 16, 64)        256
#  tchNormalization)
#
#  conv2d_11 (Conv2D)          (None, 16, 16, 64)        36928
#
#  batch_normalization_11 (Ba  (None, 16, 16, 64)        256
#  tchNormalization)
#
#  max_pooling2d_5 (MaxPoolin  (None, 8, 8, 64)          0
#  g2D)
#
#  dropout_5 (Dropout)         (None, 8, 8, 64)          0
#
#  conv2d_12 (Conv2D)          (None, 8, 8, 128)         73856
#
#  batch_normalization_12 (Ba  (None, 8, 8, 128)         512
#  tchNormalization)
#
#  conv2d_13 (Conv2D)          (None, 8, 8, 128)         147584
#
#  batch_normalization_13 (Ba  (None, 8, 8, 128)         512
#  tchNormalization)
#
#  max_pooling2d_6 (MaxPoolin  (None, 4, 4, 128)         0
#  g2D)
#
#  dropout_6 (Dropout)         (None, 4, 4, 128)         0
#
#  conv2d_14 (Conv2D)          (None, 4, 4, 256)         295168
#
#  batch_normalization_14 (Ba  (None, 4, 4, 256)         1024
#  tchNormalization)
#
#  conv2d_15 (Conv2D)          (None, 4, 4, 256)         590080
#
#  batch_normalization_15 (Ba  (None, 4, 4, 256)         1024
#  tchNormalization)
#
#  max_pooling2d_7 (MaxPoolin  (None, 2, 2, 256)         0
#  g2D)
#
#  dropout_7 (Dropout)         (None, 2, 2, 256)         0
#
#  flatten_1 (Flatten)         (None, 1024)              0
#
#  dense_2 (Dense)             (None, 64)                65600
#
#  dense_3 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 1242346 (4.74 MB)
# Trainable params: 1240426 (4.73 MB)
# Non-trainable params: 1920 (7.50 KB)
# _________________________________________________________________
# Epoch 1/40
# 704/704 [==============================] - 44s 56ms/step - loss: 1.8249 - accuracy: 0.3381 - val_loss: 1.7567 - val_accuracy: 0.4210
# Epoch 2/40
# 704/704 [==============================] - 36s 51ms/step - loss: 1.3978 - accuracy: 0.4954 - val_loss: 1.3571 - val_accuracy: 0.5384
# Epoch 3/40
# 704/704 [==============================] - 36s 51ms/step - loss: 1.1937 - accuracy: 0.5744 - val_loss: 1.1182 - val_accuracy: 0.6266
# Epoch 4/40
# 704/704 [==============================] - 36s 52ms/step - loss: 1.0514 - accuracy: 0.6284 - val_loss: 0.9970 - val_accuracy: 0.6524
# Epoch 5/40
# 704/704 [==============================] - 34s 49ms/step - loss: 0.9474 - accuracy: 0.6676 - val_loss: 0.9529 - val_accuracy: 0.6736
# Epoch 6/40
# 704/704 [==============================] - 34s 49ms/step - loss: 0.8671 - accuracy: 0.6976 - val_loss: 0.7299 - val_accuracy: 0.7504
# Epoch 7/40
# 704/704 [==============================] - 36s 51ms/step - loss: 0.8158 - accuracy: 0.7177 - val_loss: 0.8421 - val_accuracy: 0.7146
# Epoch 8/40
# 704/704 [==============================] - 35s 49ms/step - loss: 0.7743 - accuracy: 0.7328 - val_loss: 0.7405 - val_accuracy: 0.7444
# Epoch 9/40
# 704/704 [==============================] - 38s 54ms/step - loss: 0.7347 - accuracy: 0.7460 - val_loss: 0.6414 - val_accuracy: 0.7784
# Epoch 10/40
# 704/704 [==============================] - 34s 49ms/step - loss: 0.7037 - accuracy: 0.7545 - val_loss: 0.6998 - val_accuracy: 0.7604
# Epoch 11/40
# 704/704 [==============================] - 36s 51ms/step - loss: 0.6818 - accuracy: 0.7627 - val_loss: 0.6563 - val_accuracy: 0.7800
# Epoch 12/40
# 704/704 [==============================] - 35s 49ms/step - loss: 0.6473 - accuracy: 0.7769 - val_loss: 0.5612 - val_accuracy: 0.8068
# Epoch 13/40
# 704/704 [==============================] - 36s 51ms/step - loss: 0.6356 - accuracy: 0.7820 - val_loss: 0.6377 - val_accuracy: 0.7860
# Epoch 14/40
# 704/704 [==============================] - 34s 48ms/step - loss: 0.6130 - accuracy: 0.7886 - val_loss: 0.6019 - val_accuracy: 0.8026
# Epoch 15/40
# 704/704 [==============================] - 36s 51ms/step - loss: 0.5981 - accuracy: 0.7953 - val_loss: 0.5700 - val_accuracy: 0.8058
# Epoch 16/40
# 704/704 [==============================] - 34s 49ms/step - loss: 0.5802 - accuracy: 0.7973 - val_loss: 0.6410 - val_accuracy: 0.7874
# Epoch 17/40
# 704/704 [==============================] - 34s 48ms/step - loss: 0.5704 - accuracy: 0.8028 - val_loss: 0.5605 - val_accuracy: 0.8110
# Epoch 18/40
# 704/704 [==============================] - 36s 50ms/step - loss: 0.5556 - accuracy: 0.8079 - val_loss: 0.5275 - val_accuracy: 0.8212
# Epoch 19/40
# 704/704 [==============================] - 34s 48ms/step - loss: 0.5483 - accuracy: 0.8102 - val_loss: 0.5696 - val_accuracy: 0.8044
# Epoch 20/40
# 704/704 [==============================] - 35s 50ms/step - loss: 0.5269 - accuracy: 0.8156 - val_loss: 0.6572 - val_accuracy: 0.7906
# Epoch 21/40
# 704/704 [==============================] - 38s 54ms/step - loss: 0.5273 - accuracy: 0.8162 - val_loss: 0.5042 - val_accuracy: 0.8324
# Epoch 22/40
# 704/704 [==============================] - 37s 53ms/step - loss: 0.5103 - accuracy: 0.8232 - val_loss: 0.4841 - val_accuracy: 0.8326
# Epoch 23/40
# 704/704 [==============================] - 36s 52ms/step - loss: 0.5063 - accuracy: 0.8254 - val_loss: 0.5107 - val_accuracy: 0.8318
# Epoch 24/40
# 704/704 [==============================] - 38s 54ms/step - loss: 0.4978 - accuracy: 0.8288 - val_loss: 0.4469 - val_accuracy: 0.8432
# Epoch 25/40
# 704/704 [==============================] - 38s 54ms/step - loss: 0.4886 - accuracy: 0.8309 - val_loss: 0.4589 - val_accuracy: 0.8418
# Epoch 26/40
# 704/704 [==============================] - 37s 53ms/step - loss: 0.4778 - accuracy: 0.8336 - val_loss: 0.4216 - val_accuracy: 0.8596
# Epoch 27/40
# 704/704 [==============================] - 37s 52ms/step - loss: 0.4788 - accuracy: 0.8353 - val_loss: 0.4875 - val_accuracy: 0.8404
# Epoch 28/40
# 704/704 [==============================] - 38s 53ms/step - loss: 0.4714 - accuracy: 0.8379 - val_loss: 0.4770 - val_accuracy: 0.8390
# Epoch 29/40
# 704/704 [==============================] - 38s 53ms/step - loss: 0.4633 - accuracy: 0.8402 - val_loss: 0.4407 - val_accuracy: 0.8542
# Epoch 30/40
# 704/704 [==============================] - 36s 51ms/step - loss: 0.4577 - accuracy: 0.8420 - val_loss: 0.4260 - val_accuracy: 0.8598
# Epoch 31/40
# 704/704 [==============================] - 39s 56ms/step - loss: 0.4518 - accuracy: 0.8439 - val_loss: 0.4957 - val_accuracy: 0.8380
# Epoch 32/40
# 704/704 [==============================] - 38s 53ms/step - loss: 0.4436 - accuracy: 0.8451 - val_loss: 0.4459 - val_accuracy: 0.8456
# Epoch 33/40
# 704/704 [==============================] - 37s 52ms/step - loss: 0.4381 - accuracy: 0.8477 - val_loss: 0.4333 - val_accuracy: 0.8520
# Epoch 34/40
# 704/704 [==============================] - 39s 55ms/step - loss: 0.4360 - accuracy: 0.8489 - val_loss: 0.4219 - val_accuracy: 0.8546
# Epoch 35/40
# 704/704 [==============================] - 36s 51ms/step - loss: 0.4261 - accuracy: 0.8534 - val_loss: 0.4028 - val_accuracy: 0.8646
# Epoch 36/40
# 704/704 [==============================] - 37s 52ms/step - loss: 0.4261 - accuracy: 0.8524 - val_loss: 0.4472 - val_accuracy: 0.8544
# Epoch 37/40
# 704/704 [==============================] - 38s 54ms/step - loss: 0.4196 - accuracy: 0.8543 - val_loss: 0.4415 - val_accuracy: 0.8484
# Epoch 38/40
# 704/704 [==============================] - 36s 51ms/step - loss: 0.4142 - accuracy: 0.8565 - val_loss: 0.4435 - val_accuracy: 0.8512
# Epoch 39/40
# 704/704 [==============================] - 36s 51ms/step - loss: 0.4103 - accuracy: 0.8578 - val_loss: 0.4576 - val_accuracy: 0.8478
# Epoch 40/40
# 704/704 [==============================] - 37s 53ms/step - loss: 0.4068 - accuracy: 0.8591 - val_loss: 0.4119 - val_accuracy: 0.8632
# 313/313 [==============================] - 2s 6ms/step - loss: 0.4241 - accuracy: 0.8609
# Test loss: 0.42408475279808044
# Test accuracy: 0.8608999848365784

# %%
model.save("/content/gdrive/MyDrive/GG_Colab/cifar-10-batches-py/model.h5")

# %%
from tensorflow.keras.models import load_model
model = load_model('/content/gdrive/MyDrive/GG_Colab/cifar-10-batches-py/model.h5')

def show_img(path):
  resp = urllib.request.urlopen(path)
  image = np.asarray(bytearray(resp.read()), dtype="uint8")
  image = cv2.imdecode(image, cv2.IMREAD_UNCHANGED)
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  plt.imshow(image)
  plt.xticks([])
  plt.yticks([])
  plt.grid(False)
  plt.show()

def predict(path):
  resp = urllib.request.urlopen(path)
  image = np.asarray(bytearray(resp.read()), dtype="uint8")
  image = cv2.imdecode(image, cv2.IMREAD_UNCHANGED)
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

  image = cv2.resize(image, (32,32))
  image = (image-mean)/(std+1e-7)
  image = image.reshape((1, 32, 32, 3))

  prediction = model.predict(image)
  predicted_class = prediction.argmax()

  print('Predicted class: ', class_names[predicted_class])

predict("https://images2.pics4learning.com/catalog/f/frogonarm.jpg")
